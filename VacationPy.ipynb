# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     barro alto -15.1679  -48.8296    292.35        95          65
# 1        1  jumri tilaiya  24.4707   85.3849    310.63        11          96
# 2        2       bismarck  45.8767 -100.1662    272.20        91         100
# 3        3      mount isa -17.9749  140.8895    301.67        31          44
# 4        4        namdrik   5.4044  167.8402    301.63        77          33
#
#    Wind Speed Country        Date
# 0        1.74      BR  1682152839
# 1        6.72      IN  1682152842
# 2        6.26      US  1682152844
# 3        4.00      AU  1682152845
# 4        5.62      MH  1682152850

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot

map_plot = city_data_df.hvplot(kind='scatter',
    x='Lng', y='Lat', size='Humidity', hover_cols=['City'],
    color = 'City',tiles='CartoLight',
    xlabel='Longitude', ylabel='Latitude'
)

# Display the map
map_plot.opts(width=1000, height=500)
# Out:
# :Overlay
#    .Tiles.I   :Tiles   [x,y]
#    .Scatter.I :Scatter   [Lng]   (Lat,City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
city_data_df = city_data_df[city_data_df['Cloudiness'] == 0]
city_data_df = city_data_df[city_data_df['Wind Speed'] < 4.5]


# Drop any rows with null values
# YOUR CODE HERE

city_data_df = city_data_df.dropna()

# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#      City_ID                          City      Lat       Lng  Max Temp  \
# 12        12  markaz-e hukumat-e darweshan  31.5135   63.7618    303.99
# 19        19                 aldinga beach -36.5187  138.0377    290.52
# 21        21                        viedma -41.6344  -63.3531    286.46
# 33        33                     rotselaar  50.9635    4.7315    287.89
# 78        78                       abdanan  33.0010   47.2037    295.54
# 88        88                        sanger  33.4843  -97.2721    288.08
# 92        92                        robore -20.0422  -59.3747    288.65
# 93        93                        pishin  30.6624   67.1021    296.40
# 121      121                         alofi -19.9247 -169.9530    298.86
# 132      132               pereira barreto -20.8726  -51.0846    288.38
# 160      160                    san felipe  30.3805 -115.1301    288.07
# 162      162                  port augusta -29.2459  137.8416    298.04
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

hotel_df = city_data_df[['City','Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE

hotel_df['Hotel Name'] = ""

# Display sample data
# YOUR CODE HERE

hotel_df
# Out:
#                              City Country      Lat       Lng  Humidity  \
# 12   markaz-e hukumat-e darweshan      AF  31.5135   63.7618         5
# 19                  aldinga beach      AU -36.5187  138.0377        81
# 21                         viedma      AR -41.6344  -63.3531        63
# 33                      rotselaar      BE  50.9635    4.7315        81
# 78                        abdanan      IR  33.0010   47.2037        23
# 88                         sanger      US  33.4843  -97.2721        58
# 92                         robore      PY -20.0422  -59.3747        84
# 93                         pishin      PK  30.6624   67.1021         9
# 121                         alofi      NU -19.9247 -169.9530        65
# 132               pereira barreto      BR -20.8726  -51.0846        88
# 160                    san felipe      MX  30.3805 -115.1301        28
# 162                  port augusta      AU -29.2459  137.8416        28
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = "10000"
params = {
    'filter': '',
    'bias' : '',
    'api_key': geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    
    lat = city_data_df['Lat'][index]
    lng = city_data_df['Lng'][index]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = 'circle'
    params["bias"] = 'proximity'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    url = f"https://api.geoapify.com/v2/places?categories=accommodation.hotel&filter={params['filter']}:{lng},{lat},{radius}&bias={params['bias']}:{lng},{lat}&limit=20&apiKey=8715c172f1b641d8acfe2fd9c5ac1d3e" 
    
    response = requests.get(url)

    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# markaz-e hukumat-e darweshan - nearest hotel: No hotel found
# aldinga beach - nearest hotel: No hotel found
# viedma - nearest hotel: No hotel found
# rotselaar - nearest hotel: Hotel Werchter
# abdanan - nearest hotel: No hotel found
# sanger - nearest hotel: No hotel found
# robore - nearest hotel: No hotel found
# pishin - nearest hotel: No hotel found
# alofi - nearest hotel: No hotel found
# pereira barreto - nearest hotel: No hotel found
# san felipe - nearest hotel: No hotel found
# port augusta - nearest hotel: No hotel found
# qiongshan - nearest hotel: No hotel found
# rabigh - nearest hotel: No hotel found
# costa rica - nearest hotel: No hotel found
# zhangjiakou - nearest hotel: No hotel found
# qala i naw - nearest hotel: No hotel found
# villamontes - nearest hotel: No hotel found
# moree - nearest hotel: No hotel found
# shahrak - nearest hotel: No hotel found
# bardai - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot

map_plot = hotel_df.hvplot(
    kind='scatter',
    x='Lng', y='Lat', size='Humidity', hover_cols=['City','Hotel Name'],
    color = 'City',tiles='CartoLight',
    xlabel='Longitude', ylabel='Latitude'
)

# Display the map
map_plot.opts(width=800, height=500)
# Out:
# :Overlay
#    .Tiles.I   :Tiles   [x,y]
#    .Scatter.I :Scatter   [Lng]   (Lat,City,Humidity,Hotel Name)
